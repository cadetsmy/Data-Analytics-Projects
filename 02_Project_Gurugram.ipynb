# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("gurugram_data_realstate.csv")
print(df)
df.info()
print(df.columns)
# Out:
#             Price              Status  Area Rate per sqft  \
# 0      10700000.0  Under Construction  1138        9,450
# 1      14400000.0  Under Construction  1528        9,450
# 2      10700000.0  Under Construction  1138        9,450
# 3      40000000.0       Ready to move  4500        8,888
# 4      24000000.0  Under Construction  1800       13,333
# ...           ...                 ...   ...           ...
# 19510  24100000.0       Ready to move  1381       17,500
# 19511  36200000.0       Ready to move  2072       17,500
# 19512  39100000.0  Under Construction  2445       16,002
# 19513  37700000.0  Under Construction  2360       16,001
# 19514  36500000.0  Under Construction  2282       16,005
#
#                                            Property Type    Locality  \
# 0           2 BHK Apartment in M3M Antalya Hills Phase I   Sector 79
# 1           3 BHK Apartment in M3M Antalya Hills Phase I   Sector 79
# 2           2 BHK Apartment in M3M Antalya Hills Phase I   Sector 79
# 3                                4 BHK Independent Floor   Sector 57
# 4      3 BHK Independent Floor in Anant Raj Estate Plots   Sector 63
# ...                                                  ...         ...
# 19510                      2 BHK Apartment in Sobha City  Sector 108
# 19511                      3 BHK Apartment in Sobha City  Sector 108
# 19512                   3 BHK Apartment in Pyramid Alban   Sector 71
# 19513                   3 BHK Apartment in Pyramid Alban   Sector 71
# 19514                   3 BHK Apartment in Pyramid Alban   Sector 71
#
#                          Builder Name         RERA Approval  BHK_Count  \
# 0                                home      Approved by RERA        2.0
# 1                 Property In Gurgaon      Approved by RERA        3.0
# 2      properties for sale in Gurgaon      Approved by RERA        2.0
# 3                    MM India Pvt Ltd  Not approved by RERA        4.0
# 4                    MM India Pvt Ltd      Approved by RERA        3.0
# ...                               ...                   ...        ...
# 19510              Shree Realstic One  Not approved by RERA        2.0
# 19511              Shree Realstic One  Not approved by RERA        3.0
# 19512              Shree Realstic One      Approved by RERA        3.0
# 19513              Shree Realstic One      Approved by RERA        3.0
# 19514              Shree Realstic One      Approved by RERA        3.0
#
#                            Socity Company Name  Flat Type
# 0       M3M Antalya Hills Phase I          M3M  Apartment
# 1       M3M Antalya Hills Phase I          M3M  Apartment
# 2       M3M Antalya Hills Phase I          M3M  Apartment
# 3                  Outside Socity      Outside       Plot
# 4          Anant Raj Estate Plots        Anant      Floor
# ...                           ...          ...        ...
# 19510                  Sobha City        Sobha  Apartment
# 19511                  Sobha City        Sobha  Apartment
# 19512               Pyramid Alban      Pyramid  Apartment
# 19513               Pyramid Alban      Pyramid  Apartment
# 19514               Pyramid Alban      Pyramid  Apartment
#
# [19515 rows x 12 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19515 entries, 0 to 19514
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          19515 non-null  object
#  1   Status         19515 non-null  object
#  2   Area           19515 non-null  int64
#  3   Rate per sqft  19515 non-null  object
#  4   Property Type  19515 non-null  object
#  5   Locality       19515 non-null  object
#  6   Builder Name   19515 non-null  object
#  7   RERA Approval  19515 non-null  object
#  8   BHK_Count      19515 non-null  float64
#  9   Socity         19515 non-null  object
#  10  Company Name   19515 non-null  object
#  11  Flat Type      19515 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 1.8+ MB
# Index(['Price', 'Status', 'Area', 'Rate per sqft', 'Property Type', 'Locality',
#        'Builder Name', 'RERA Approval', 'BHK_Count', 'Socity', 'Company Name',
#        'Flat Type'],
#       dtype='object')

# %% [markdown]
# # In this we find the answer of the questions:
# 1. Which is the costliest flat in the dataset?
# 2. Which locality has the highest average price?
# 3. Which locality has the highest rate per square foot?
# 4. Do ready-to-move properties cost more than under-construction properties?
# 5. Do RERA-approved properties command a price premium?
# 6. How does area (sqft) impact property price?
# 7. Which BHK configuration is the most expensive on average?
# 8. Which property type (Apartment, Floor, Plot) is the costliest?
# 9. Do certain builders or companies consistently price higher?
# 10. Are larger homes always more expensive per square foot?

# %%
# cleaning the data:
df.columns = df.columns.str.strip().str.upper().str.replace(" ", "_")
print("This is the columns")
print(df.columns)
df = df.drop_duplicates()
df.info()
df["SOCIETY"] = df["SOCITY"]
print(df)
print(df.columns)
df.info()
# Out:
# This is the columns
# Index(['PRICE', 'STATUS', 'AREA', 'RATE_PER_SQFT', 'PROPERTY_TYPE', 'LOCALITY',
#        'BUILDER_NAME', 'RERA_APPROVAL', 'BHK_COUNT', 'SOCITY', 'COMPANY_NAME',
#        'FLAT_TYPE', 'SOCIETY'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 14223 entries, 0 to 19514
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRICE          14223 non-null  float64
#  1   STATUS         14223 non-null  object
#  2   AREA           14223 non-null  int64
#  3   RATE_PER_SQFT  14223 non-null  int64
#  4   PROPERTY_TYPE  14223 non-null  object
#  5   LOCALITY       14223 non-null  object
#  6   BUILDER_NAME   14223 non-null  object
#  7   RERA_APPROVAL  0 non-null      object
#  8   BHK_COUNT      14223 non-null  float64
#  9   SOCITY         14223 non-null  object
#  10  COMPANY_NAME   14223 non-null  object
#  11  FLAT_TYPE      14223 non-null  object
#  12  SOCIETY        14223 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.5+ MB
#             PRICE              STATUS  AREA  RATE_PER_SQFT  \
# 0      10700000.0  under construction  1138           9450
# 1      14400000.0  under construction  1528           9450
# 2      10700000.0  under construction  1138           9450
# 3      40000000.0       ready to move  4500           8888
# 4      24000000.0  under construction  1800          13333
# ...           ...                 ...   ...            ...
# 19510  24100000.0       ready to move  1381          17500
# 19511  36200000.0       ready to move  2072          17500
# 19512  39100000.0  under construction  2445          16002
# 19513  37700000.0  under construction  2360          16001
# 19514  36500000.0  under construction  2282          16005
#
#                                            PROPERTY_TYPE    LOCALITY  \
# 0           2 BHK Apartment in M3M Antalya Hills Phase I   Sector 79
# 1           3 BHK Apartment in M3M Antalya Hills Phase I   Sector 79
# 2           2 BHK Apartment in M3M Antalya Hills Phase I   Sector 79
# 3                                4 BHK Independent Floor   Sector 57
# 4      3 BHK Independent Floor in Anant Raj Estate Plots   Sector 63
# ...                                                  ...         ...
# 19510                      2 BHK Apartment in Sobha City  Sector 108
# 19511                      3 BHK Apartment in Sobha City  Sector 108
# 19512                   3 BHK Apartment in Pyramid Alban   Sector 71
# 19513                   3 BHK Apartment in Pyramid Alban   Sector 71
# 19514                   3 BHK Apartment in Pyramid Alban   Sector 71
#
#                          BUILDER_NAME RERA_APPROVAL  BHK_COUNT  \
# 0                                home           NaN        2.0
# 1                 Property In Gurgaon           NaN        3.0
# 2      properties for sale in Gurgaon           NaN        2.0
# 3                    MM India Pvt Ltd           NaN        4.0
# 4                    MM India Pvt Ltd           NaN        3.0
# ...                               ...           ...        ...
# 19510              Shree Realstic One           NaN        2.0
# 19511              Shree Realstic One           NaN        3.0
# 19512              Shree Realstic One           NaN        3.0
# 19513              Shree Realstic One           NaN        3.0
# 19514              Shree Realstic One           NaN        3.0
#
#                            SOCITY COMPANY_NAME  FLAT_TYPE  \
# 0       M3M Antalya Hills Phase I          M3M  Apartment
# 1       M3M Antalya Hills Phase I          M3M  Apartment
# 2       M3M Antalya Hills Phase I          M3M  Apartment
# 3                  Outside Socity      Outside       Plot
# 4          Anant Raj Estate Plots        Anant      Floor
# ...                           ...          ...        ...
# 19510                  Sobha City        Sobha  Apartment
# 19511                  Sobha City        Sobha  Apartment
# 19512               Pyramid Alban      Pyramid  Apartment
# 19513               Pyramid Alban      Pyramid  Apartment
# 19514               Pyramid Alban      Pyramid  Apartment
#
#                           SOCIETY
# 0       M3M Antalya Hills Phase I
# 1       M3M Antalya Hills Phase I
# 2       M3M Antalya Hills Phase I
# 3                  Outside Socity
# 4          Anant Raj Estate Plots
# ...                           ...
# 19510                  Sobha City
# 19511                  Sobha City
# 19512               Pyramid Alban
# 19513               Pyramid Alban
# 19514               Pyramid Alban
#
# [14223 rows x 13 columns]
# Index(['PRICE', 'STATUS', 'AREA', 'RATE_PER_SQFT', 'PROPERTY_TYPE', 'LOCALITY',
#        'BUILDER_NAME', 'RERA_APPROVAL', 'BHK_COUNT', 'SOCITY', 'COMPANY_NAME',
#        'FLAT_TYPE', 'SOCIETY'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 14223 entries, 0 to 19514
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRICE          14223 non-null  float64
#  1   STATUS         14223 non-null  object
#  2   AREA           14223 non-null  int64
#  3   RATE_PER_SQFT  14223 non-null  int64
#  4   PROPERTY_TYPE  14223 non-null  object
#  5   LOCALITY       14223 non-null  object
#  6   BUILDER_NAME   14223 non-null  object
#  7   RERA_APPROVAL  0 non-null      object
#  8   BHK_COUNT      14223 non-null  float64
#  9   SOCITY         14223 non-null  object
#  10  COMPANY_NAME   14223 non-null  object
#  11  FLAT_TYPE      14223 non-null  object
#  12  SOCIETY        14223 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.5+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14223 entries, 0 to 19514
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRICE          14223 non-null  float64
#  1   STATUS         14223 non-null  object
#  2   AREA           14223 non-null  int64
#  3   RATE_PER_SQFT  14223 non-null  int64
#  4   PROPERTY_TYPE  14223 non-null  object
#  5   LOCALITY       14223 non-null  object
#  6   BUILDER_NAME   14223 non-null  object
#  7   RERA_APPROVAL  14223 non-null  bool
#  8   BHK_COUNT      14223 non-null  float64
#  9   SOCITY         14223 non-null  object
#  10  COMPANY_NAME   14223 non-null  object
#  11  FLAT_TYPE      14223 non-null  object
#  12  SOCIETY        14223 non-null  object
# dtypes: bool(1), float64(2), int64(2), object(8)
# memory usage: 1.4+ MB

# %%
# now we convert the price into the numeric:
# its a numeric columns cleaning:
df["PRICE"] = df["PRICE"].astype(str).str.replace(",","").astype(float)
print(df["PRICE"])
# df.info()
df["AREA"] = df["AREA"].astype(str).str.replace(",","").astype(int)
print(df["AREA"])
df["RATE_PER_SQFT"] = df["RATE_PER_SQFT"].astype(str).str.replace(",", "").astype(int)
print("this is the rate per square foot")
print(df["RATE_PER_SQFT"])
# df.info()
# Out:
# 0        10700000.0
# 1        14400000.0
# 2        10700000.0
# 3        40000000.0
# 4        24000000.0
#             ...
# 19510    24100000.0
# 19511    36200000.0
# 19512    39100000.0
# 19513    37700000.0
# 19514    36500000.0
# Name: PRICE, Length: 14223, dtype: float64
# 0        1138
# 1        1528
# 2        1138
# 3        4500
# 4        1800
#          ...
# 19510    1381
# 19511    2072
# 19512    2445
# 19513    2360
# 19514    2282
# Name: AREA, Length: 14223, dtype: int64
# this is the rate per square foot
# 0         9450
# 1         9450
# 2         9450
# 3         8888
# 4        13333
#          ...
# 19510    17500
# 19511    17500
# 19512    16002
# 19513    16001
# 19514    16005
# Name: RATE_PER_SQFT, Length: 14223, dtype: int64

# %%
# It is the categorical columns cleaning:
df["STATUS"] = df["STATUS"].str.strip().str.lower()
df["RERA_APPROVAL"] = df["RERA_APPROVAL"].astype(str).str.strip().str.lower().map({"approved by rera":True, "not approved by rera":False})
print(df["RERA_APPROVAL"])
df.info()
column = df["RERA_APPROVAL"]
print(column)
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 19510    NaN
# 19511    NaN
# 19512    NaN
# 19513    NaN
# 19514    NaN
# Name: RERA_APPROVAL, Length: 14223, dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Index: 14223 entries, 0 to 19514
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRICE          14223 non-null  float64
#  1   STATUS         14223 non-null  object
#  2   AREA           14223 non-null  int64
#  3   RATE_PER_SQFT  14223 non-null  int64
#  4   PROPERTY_TYPE  14223 non-null  object
#  5   LOCALITY       14223 non-null  object
#  6   BUILDER_NAME   14223 non-null  object
#  7   RERA_APPROVAL  0 non-null      object
#  8   BHK_COUNT      14223 non-null  float64
#  9   SOCITY         14223 non-null  object
#  10  COMPANY_NAME   14223 non-null  object
#  11  FLAT_TYPE      14223 non-null  object
#  12  SOCIETY        14223 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.5+ MB
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 19510    NaN
# 19511    NaN
# 19512    NaN
# 19513    NaN
# 19514    NaN
# Name: RERA_APPROVAL, Length: 14223, dtype: object
